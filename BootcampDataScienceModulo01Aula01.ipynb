# %% [markdown]
# <a href="https://colab.research.google.com/github/silviacfreitas/DataScienceAplicadaAlura/blob/main/BootcampDataScienceModulo01Aula01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Análise dos dados do DataSUS a partir de 2008

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# %%
dados = pd.read_csv("/content/A151346189_28_143_208.csv", encoding="ISO-8859-1", 
                    skiprows=3, sep=";", skipfooter=12,
                    thousands=".", decimal=",",
                    na_values='-')
dados
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   after removing the cwd from sys.path.
#       Unidade da Federação     2008/Jan  ...      2020/Ago         Total
# 0              11 Rondônia   1388528.39  ...  1.028546e+07  9.291297e+08
# 1                  12 Acre    902416.00  ...           NaN  4.206680e+08
# 2              13 Amazonas   4735529.42  ...  1.472644e+07  1.771655e+09
# 3               14 Roraima    657889.53  ...  2.826486e+06  3.050109e+08
# 4                  15 Pará  18864744.11  ...  3.991119e+07  4.437116e+09
# 5                 16 Amapá   1120973.34  ...  2.942274e+06  2.916380e+08
# 6             17 Tocantins   3441592.69  ...  8.240261e+06  9.999986e+08
# 7              21 Maranhão  10723506.39  ...  2.858754e+07  3.632861e+09
# 8                 22 Piauí   7985142.43  ...  2.321062e+07  2.130616e+09
# 9                 23 Ceará  15539821.90  ...  5.980861e+07  6.197357e+09
# 10  24 Rio Grande do Norte   5947814.08  ...  2.492993e+07  2.477372e+09
# 11              25 Paraíba  10723002.45  ...  2.213002e+07  2.470550e+09
# 12           26 Pernambuco  14393949.89  ...  7.570418e+07  8.046954e+09
# 13              27 Alagoas   6243726.32  ...  1.975474e+07  2.104405e+09
# 14              28 Sergipe   2780750.11  ...  1.101418e+07  1.130337e+09
# 15                29 Bahia  21211522.47  ...  8.079312e+07  9.193803e+09
# 16         31 Minas Gerais  45671659.76  ...  1.680244e+08  1.916011e+10
# 17       32 Espírito Santo   5456723.98  ...  3.218887e+07  3.139189e+09
# 18       33 Rio de Janeiro  23025258.52  ...  9.527449e+07  9.696364e+09
# 19            35 São Paulo  91678473.48  ...  3.465123e+08  3.892955e+10
# 20               41 Paraná  38266347.46  ...  1.293759e+08  1.378696e+10
# 21       42 Santa Catarina  16504913.45  ...  6.397238e+07  7.324100e+09
# 22    43 Rio Grande do Sul  30931325.46  ...  1.013743e+08  1.195865e+10
# 23   50 Mato Grosso do Sul   5377392.11  ...  1.924162e+07  2.172158e+09
# 24          51 Mato Grosso   4795299.01  ...  1.779065e+07  2.036924e+09
# 25                52 Goiás  15310637.29  ...  4.398470e+07  4.657350e+09
# 26     53 Distrito Federal   4745919.19  ...  2.652620e+07  2.429933e+09
#
# [27 rows x 154 columns]

# %%
dados.head()
# Out:
#   Unidade da Federação     2008/Jan  ...     2020/Ago         Total
# 0          11 Rondônia   1388528.39  ...  10285455.78  9.291297e+08
# 1              12 Acre    902416.00  ...          NaN  4.206680e+08
# 2          13 Amazonas   4735529.42  ...  14726443.67  1.771655e+09
# 3           14 Roraima    657889.53  ...   2826486.18  3.050109e+08
# 4              15 Pará  18864744.11  ...  39911193.02  4.437116e+09
#
# [5 rows x 154 columns]

# %%
dados.tail()
# Out:
#      Unidade da Federação     2008/Jan  ...      2020/Ago         Total
# 22   43 Rio Grande do Sul  30931325.46  ...  1.013743e+08  1.195865e+10
# 23  50 Mato Grosso do Sul   5377392.11  ...  1.924162e+07  2.172158e+09
# 24         51 Mato Grosso   4795299.01  ...  1.779065e+07  2.036924e+09
# 25               52 Goiás  15310637.29  ...  4.398470e+07  4.657350e+09
# 26    53 Distrito Federal   4745919.19  ...  2.652620e+07  2.429933e+09
#
# [5 rows x 154 columns]

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Columns: 154 entries, Unidade da Federação to Total
# dtypes: float64(153), object(1)
# memory usage: 32.6+ KB

# %%
dados.mean()
# Out:
# 2008/Jan    1.512685e+07
# 2008/Fev    2.271016e+07
# 2008/Mar    2.459419e+07
# 2008/Abr    2.543196e+07
# 2008/Mai    2.651125e+07
#                 ...
# 2020/Mai    4.419363e+07
# 2020/Jun    4.732999e+07
# 2020/Jul    5.449551e+07
# 2020/Ago    5.650503e+07
# Total       5.993732e+09
# Length: 153, dtype: float64

# %%
pd.options.display.float_format = "{:.2f}".format

# %%
dados.mean()
# Out:
# 2008/Jan     15126846.64
# 2008/Fev     22710158.12
# 2008/Mar     24594187.35
# 2008/Abr     25431957.83
# 2008/Mai     26511245.91
#                 ...
# 2020/Mai     44193633.75
# 2020/Jun     47329994.46
# 2020/Jul     54495511.57
# 2020/Ago     56505034.29
# Total      5993731798.30
# Length: 153, dtype: float64

# %%
dados["2008/Ago"].mean()
# Out:
# 27800320.306666665

# %%
dados.plot(x="Unidade da Federação", y="2008/Ago")

# %%
dados.plot(x="Unidade da Federação", y="2008/Ago", kind="bar", figsize=(10,6))

# %%
ax = dados.plot(x="Unidade da Federação", y="2008/Ago", kind="bar", figsize=(10,6))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
plt.title("Valor gasto em procedimentos hospitalares pelo SUS por Unidade da Federação")
plt.show()

# %%
ax = dados.sort_values("2020/Ago", ascending=False).plot(x="Unidade da Federação", y="2020/Ago", kind="bar", figsize=(10,6))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
plt.title("Valor gasto em procedimentos hospitalares pelo SUS por Unidade da Federação")
plt.show()

# %% [markdown]
# Análise dos dados do DataSUS a partir de 2008

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# %%
dados = pd.read_csv("/content/A160324189_28_143_208.csv", encoding="ISO-8859-1", 
                    skiprows=3, sep=";", skipfooter=12,
                    thousands=".", decimal=",")
                    # na_values='-')
dados
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   This is separate from the ipykernel package so we can avoid doing imports until
#       Unidade da Federação  1992/Mar  ...      2020/Ago         Total
# 0              11 Rondônia         -  ...    3556381.57  9.291297e+08
# 1                  12 Acre         -  ...             -  4.206680e+08
# 2              13 Amazonas         -  ...    4726485.73  1.771655e+09
# 3               14 Roraima         -  ...    1524478.04  3.050109e+08
# 4                  15 Pará         -  ...   11559714.54  4.437116e+09
# 5                 16 Amapá         -  ...     834187.31  2.916380e+08
# 6             17 Tocantins         -  ...    2453362.74  9.999986e+08
# 7              21 Maranhão         -  ...   10916718.78  3.632861e+09
# 8                 22 Piauí         -  ...    7926321.69  2.130616e+09
# 9                 23 Ceará         -  ...   14559529.59  6.197357e+09
# 10  24 Rio Grande do Norte         -  ...    8080160.97  2.477372e+09
# 11              25 Paraíba         -  ...    8585226.08  2.470550e+09
# 12           26 Pernambuco         -  ...   33544876.14  8.046954e+09
# 13              27 Alagoas         -  ...    6487947.82  2.104405e+09
# 14              28 Sergipe         -  ...    1742127.72  1.130337e+09
# 15                29 Bahia         -  ...   26023558.53  9.193803e+09
# 16         31 Minas Gerais         -  ...   57473699.06  1.916011e+10
# 17       32 Espírito Santo         -  ...   10824255.26  3.139189e+09
# 18       33 Rio de Janeiro         -  ...   36264322.65  9.696363e+09
# 19            35 São Paulo  40243.16  ...  140414944.95  3.892935e+10
# 20               41 Paraná         -  ...   41542401.16  1.378696e+10
# 21       42 Santa Catarina         -  ...   16991236.43  7.324100e+09
# 22    43 Rio Grande do Sul         -  ...   28349257.38  1.195865e+10
# 23   50 Mato Grosso do Sul         -  ...    4059220.22  2.172158e+09
# 24          51 Mato Grosso         -  ...    6174224.99  2.036924e+09
# 25                52 Goiás         -  ...   20242641.73  4.657349e+09
# 26     53 Distrito Federal         -  ...   12044848.02  2.429933e+09
#
# [27 rows x 280 columns]

# %%
dados.head()
# Out:
#   Unidade da Federação 1992/Mar  ...     2020/Ago         Total
# 0          11 Rondônia        -  ...   3556381.57  9.291297e+08
# 1              12 Acre        -  ...            -  4.206680e+08
# 2          13 Amazonas        -  ...   4726485.73  1.771655e+09
# 3           14 Roraima        -  ...   1524478.04  3.050109e+08
# 4              15 Pará        -  ...  11559714.54  4.437116e+09
#
# [5 rows x 280 columns]

# %%
dados.tail()
# Out:
#      Unidade da Federação 1992/Mar  ...     2020/Ago         Total
# 22   43 Rio Grande do Sul        -  ...  28349257.38  1.195865e+10
# 23  50 Mato Grosso do Sul        -  ...   4059220.22  2.172158e+09
# 24         51 Mato Grosso        -  ...   6174224.99  2.036924e+09
# 25               52 Goiás        -  ...  20242641.73  4.657349e+09
# 26    53 Distrito Federal        -  ...  12044848.02  2.429933e+09
#
# [5 rows x 280 columns]

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Columns: 280 entries, Unidade da Federação to Total
# dtypes: float64(157), object(123)
# memory usage: 59.2+ KB

# %%
dados.mean()
# Out:
# 2007/Ago    3.049528e+05
# 2007/Set    7.881453e+05
# 2007/Out    2.440163e+06
# 2007/Nov    5.517354e+06
# 2007/Dez    1.233716e+07
#                 ...
# 2020/Abr    4.000568e+07
# 2020/Mai    4.676903e+07
# 2020/Jun    4.536735e+07
# 2020/Jul    4.071708e+07
# Total       5.993724e+09
# Length: 157, dtype: float64

# %%
pd.options.display.float_format = "{:.2f}".format

# %%
dados.mean()
# Out:
# 2007/Ago       304952.77
# 2007/Set       788145.26
# 2007/Out      2440162.96
# 2007/Nov      5517354.05
# 2007/Dez     12337159.42
#                 ...
# 2020/Abr     40005678.92
# 2020/Mai     46769027.82
# 2020/Jun     45367349.74
# 2020/Jul     40717083.95
# Total      5993724452.01
# Length: 157, dtype: float64

# %%
dados["2008/Ago"].mean()
# Out:
# 26636409.892222222

# %%
dados.plot(x="Unidade da Federação", y="2008/Ago")

# %%
dados.plot(x="Unidade da Federação", y="2008/Ago", kind="bar", figsize=(10,6))

# %%
ax = dados.plot(x="Unidade da Federação", y="2008/Ago", kind="bar", figsize=(10,6))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
plt.title("Valor gasto em procedimentos hospitalares pelo SUS por Unidade da Federação")
plt.show()

# %%
ax = dados.plot(x="Unidade da Federação", y="2020/Jul", kind="bar", figsize=(10,6))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
plt.title("Valor gasto em procedimentos hospitalares pelo SUS por Unidade da Federação")
plt.show()

# %% [markdown]
# Análise dos dados do DataSUS a partir de 2008

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# %%
dados = pd.read_csv("/content/A160324189_28_143_208.csv", encoding="ISO-8859-1", 
                    skiprows=3, sep=";", skipfooter=12,
                    thousands=".", decimal=",")
                    # na_values='-')
dados
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   This is separate from the ipykernel package so we can avoid doing imports until
#       Unidade da Federação  1992/Mar  ...      2020/Ago         Total
# 0              11 Rondônia         -  ...    3556381.57  9.291297e+08
# 1                  12 Acre         -  ...             -  4.206680e+08
# 2              13 Amazonas         -  ...    4726485.73  1.771655e+09
# 3               14 Roraima         -  ...    1524478.04  3.050109e+08
# 4                  15 Pará         -  ...   11559714.54  4.437116e+09
# 5                 16 Amapá         -  ...     834187.31  2.916380e+08
# 6             17 Tocantins         -  ...    2453362.74  9.999986e+08
# 7              21 Maranhão         -  ...   10916718.78  3.632861e+09
# 8                 22 Piauí         -  ...    7926321.69  2.130616e+09
# 9                 23 Ceará         -  ...   14559529.59  6.197357e+09
# 10  24 Rio Grande do Norte         -  ...    8080160.97  2.477372e+09
# 11              25 Paraíba         -  ...    8585226.08  2.470550e+09
# 12           26 Pernambuco         -  ...   33544876.14  8.046954e+09
# 13              27 Alagoas         -  ...    6487947.82  2.104405e+09
# 14              28 Sergipe         -  ...    1742127.72  1.130337e+09
# 15                29 Bahia         -  ...   26023558.53  9.193803e+09
# 16         31 Minas Gerais         -  ...   57473699.06  1.916011e+10
# 17       32 Espírito Santo         -  ...   10824255.26  3.139189e+09
# 18       33 Rio de Janeiro         -  ...   36264322.65  9.696363e+09
# 19            35 São Paulo  40243.16  ...  140414944.95  3.892935e+10
# 20               41 Paraná         -  ...   41542401.16  1.378696e+10
# 21       42 Santa Catarina         -  ...   16991236.43  7.324100e+09
# 22    43 Rio Grande do Sul         -  ...   28349257.38  1.195865e+10
# 23   50 Mato Grosso do Sul         -  ...    4059220.22  2.172158e+09
# 24          51 Mato Grosso         -  ...    6174224.99  2.036924e+09
# 25                52 Goiás         -  ...   20242641.73  4.657349e+09
# 26     53 Distrito Federal         -  ...   12044848.02  2.429933e+09
#
# [27 rows x 280 columns]

# %%
dados.head()
# Out:
#   Unidade da Federação 1992/Mar  ...     2020/Ago         Total
# 0          11 Rondônia        -  ...   3556381.57  9.291297e+08
# 1              12 Acre        -  ...            -  4.206680e+08
# 2          13 Amazonas        -  ...   4726485.73  1.771655e+09
# 3           14 Roraima        -  ...   1524478.04  3.050109e+08
# 4              15 Pará        -  ...  11559714.54  4.437116e+09
#
# [5 rows x 280 columns]

# %%
dados.tail()
# Out:
#      Unidade da Federação 1992/Mar  ...     2020/Ago         Total
# 22   43 Rio Grande do Sul        -  ...  28349257.38  1.195865e+10
# 23  50 Mato Grosso do Sul        -  ...   4059220.22  2.172158e+09
# 24         51 Mato Grosso        -  ...   6174224.99  2.036924e+09
# 25               52 Goiás        -  ...  20242641.73  4.657349e+09
# 26    53 Distrito Federal        -  ...  12044848.02  2.429933e+09
#
# [5 rows x 280 columns]

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Columns: 280 entries, Unidade da Federação to Total
# dtypes: float64(157), object(123)
# memory usage: 59.2+ KB

# %%
dados.mean()
# Out:
# 2007/Ago    3.049528e+05
# 2007/Set    7.881453e+05
# 2007/Out    2.440163e+06
# 2007/Nov    5.517354e+06
# 2007/Dez    1.233716e+07
#                 ...
# 2020/Abr    4.000568e+07
# 2020/Mai    4.676903e+07
# 2020/Jun    4.536735e+07
# 2020/Jul    4.071708e+07
# Total       5.993724e+09
# Length: 157, dtype: float64

# %%
pd.options.display.float_format = "{:.2f}".format

# %%
dados.mean()
# Out:
# 2007/Ago       304952.77
# 2007/Set       788145.26
# 2007/Out      2440162.96
# 2007/Nov      5517354.05
# 2007/Dez     12337159.42
#                 ...
# 2020/Abr     40005678.92
# 2020/Mai     46769027.82
# 2020/Jun     45367349.74
# 2020/Jul     40717083.95
# Total      5993724452.01
# Length: 157, dtype: float64

# %%
dados["2008/Ago"].mean()
# Out:
# 26636409.892222222

# %%
dados.plot(x="Unidade da Federação", y="2008/Ago")

# %%
dados.plot(x="Unidade da Federação", y="2008/Ago", kind="bar", figsize=(10,6))

# %%
ax = dados.plot(x="Unidade da Federação", y="2008/Ago", kind="bar", figsize=(10,6))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
plt.title("Valor gasto em procedimentos hospitalares pelo SUS por Unidade da Federação")
plt.show()

# %%
ax = dados.sort_values("2020/Ago", ascending=False).plot(x="Unidade da Federação", y="2020/Ago", kind="bar", figsize=(10,6))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
plt.title("Valor gasto em procedimentos hospitalares pelo SUS por Unidade da Federação")
plt.show()
